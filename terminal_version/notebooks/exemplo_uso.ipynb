# %% [markdown]
# # Exemplo de uso — Versão Terminal

# %%
from comparador_fbref_tm import coleta_dados, processamento, analise, visualizacao
# df_fbref, df_tm = coleta_dados.carregar_fontes(...)
# df = processamento.comparar(df_fbref, df_tm)
# analise.exibir_resultados(df)
# visualizacao.graficos(df)
